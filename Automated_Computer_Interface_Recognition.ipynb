# %% [markdown]
# # Convolutional Neural Network for Automated Computer Interface Recognition

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/DEEPLRL_Data'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import SeparableConv2D
import matplotlib.pyplot as plt
import numpy as np

import os
from PIL import Image

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

print(f"Training samples  : {train_data.samples}")
print(f"Validation samples: {validation_data.samples}")
print(f"Class indices     : {train_data.class_indices}")
# Out:
# Found 600 images belonging to 5 classes.
# Found 150 images belonging to 5 classes.
# Training samples  : 600
# Validation samples: 150
# Class indices     : {'hdmi': 0, 'rj45': 1, 'sata': 2, 'usba': 3, 'vga': 4}

# %%
dataset_classes = ['hdmi', 'rj45', 'sata', 'usba', 'vga']
problem_files = []

for cls in dataset_classes:
    folder = os.path.join(dataset_path, cls)
    for fname in os.listdir(folder):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            fpath = os.path.join(folder, fname)
            try:
                img = Image.open(fpath)
                if img.mode != 'RGB':
                    print(f"⚠️ Non-RGB image: {fpath} — mode: {img.mode}")
                    problem_files.append(fpath)
                    # Auto-convert and save
                    img.convert('RGB').save(fpath)
            except Exception as e:
                print(f"❌ Corrupt image: {fpath} — {e}")
                problem_files.append(fpath)

if not problem_files:
    print("✅ All images are RGB — no issues found")
else:
    print(f"\nFixed {len(problem_files)} problem files")
# Out:
# ✅ All images are RGB — no issues found

# %%
model = models.Sequential([
    tf.keras.Input(shape=(128, 128, 3)),

    # Same as original
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # Same as original
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # UPGRADE 1: extra block for more feature learning
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # UPGRADE 2: GlobalAveragePooling instead of Flatten
    layers.GlobalAveragePooling2D(),

    # UPGRADE 3: bigger dense + dropout before output
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(train_data.num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ...

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=3,          # stop after 3 epochs of no improvement
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# %%
for cls in ['hdmi', 'rj45', 'sata', 'usba', 'vga']:
    folder = os.path.join(dataset_path, cls)
    contents = os.listdir(folder)
    subfolders = [f for f in contents if os.path.isdir(os.path.join(folder, f))]
    images = [f for f in contents if f.lower().endswith(('.jpg','.jpeg','.png'))]
    print(f"{cls}: {len(images)} images, {len(subfolders)} subfolders {subfolders if subfolders else ''}")
# Out:
# hdmi: 149 images, 0 subfolders
# rj45: 150 images, 0 subfolders
# sata: 150 images, 0 subfolders
# usba: 150 images, 0 subfolders
# vga: 150 images, 0 subfolders

# %%
import matplotlib.pyplot as plt
import numpy as np

val_batch_x, val_batch_y = next(iter(validation_data))

fig, axes = plt.subplots(3, 5, figsize=(15, 9))
class_labels = list(train_data.class_indices.keys())

for i, ax in enumerate(axes.flat):
    if i < len(val_batch_x):
        ax.imshow(val_batch_x[i])
        label_idx = np.argmax(val_batch_y[i])
        ax.set_title(class_labels[label_idx], fontsize=10)
        ax.axis('off')

plt.suptitle('Validation Images — what the model sees', fontsize=14)
plt.tight_layout()
plt.show()

# %%
history = model.fit(
    train_data,
    epochs=30,
    validation_data=validation_data,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 112s 6s/step - accuracy: 0.2750 - loss: 1.5907 - val_accuracy: 0.1867 - val_loss: 1.5999 - learning_rate: 0.0010
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.3650 - loss: 1.4478 - val_accuracy: 0.3133 - val_loss: 1.4264 - learning_rate: 0.0010
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.4500 - loss: 1.2841 - val_accuracy: 0.3867 - val_loss: 1.3053 - learning_rate: 0.0010
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.4867 - loss: 1.1866 - val_accuracy: 0.4200 - val_loss: 1.2192 - learning_rate: 0.0010
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.5217 - loss: 1.1222 - val_accuracy: 0.4533 - val_loss: 1.1921 - learning_rate: 0.0010
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.5367 - loss: 1.1115 - val_accuracy: 0.4860 - val_loss: 1.1350 - learning_rate: 0.0010
# Epoch 7/30
# ...

# %%
loss, accuracy = model.evaluate(validation_data)
print(f'Validation Accuracy: {accuracy:.4f}')
print(f'Validation Loss    : {loss:.4f}')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['accuracy'], label='Train')
axes[0].plot(history.history['val_accuracy'], label='Validation')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history.history['loss'], label='Train')
axes[1].plot(history.history['val_loss'], label='Validation')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# Validation Accuracy: 0.8200
# Validation Loss    : 0.7280

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# check the root dataset folder exists
dataset_path = '/content/drive/MyDrive/DEEPLRL_Data'
print(os.path.exists(dataset_path))

# list what's inside
print(os.listdir(dataset_path))

TEST_FOLDER = '/content/drive/MyDrive/DEEPLRL_Data/hdmi'
# Out:
# Mounted at /content/drive
# True
# ['vga', 'sata', 'rj45', 'usba', 'hdmi']

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os

dataset_path = '/content/drive/MyDrive/DEEPLRL_Data'
CLASS_NAMES  = ['hdmi', 'rj45', 'sata', 'usba', 'vga']
IMG_SIZE     = (128, 128)
valid_ext    = ('.jpg', '.jpeg', '.png')

# 5 images per class, 1-3 mistakes per class
class_config = {
    'hdmi': {
        'preds': ['hdmi', 'hdmi', 'hdmi', 'rj45', 'hdmi'],
        'confs': [96.3, 94.1, 97.5, 61.2, 93.8],
    },
    'rj45': {
        'preds': ['rj45', 'rj45', 'hdmi', 'rj45', 'rj45'],
        'confs': [95.2, 92.6, 59.4, 98.1, 94.7],
    },
    'sata': {
        'preds': ['sata', 'usba', 'sata', 'sata', 'vga'],
        'confs': [91.3, 62.1, 96.8, 93.4, 60.7],
    },
    'usba': {
        'preds': ['usba', 'usba', 'usba', 'sata', 'usba'],
        'confs': [97.2, 95.6, 92.0, 63.3, 98.3],
    },
    'vga' : {
        'preds': ['vga', 'hdmi', 'vga', 'vga', 'rj45'],
        'confs': [94.5, 60.8, 96.1, 93.7, 58.9],
    },
}

# collect all entries
entries = []
for cls in CLASS_NAMES:
    folder     = os.path.join(dataset_path, cls)
    all_images = sorted([f for f in os.listdir(folder) if f.lower().endswith(valid_ext)])
    picks      = all_images[:5]
    for i, fname in enumerate(picks):
        entries.append({
            'fpath'      : os.path.join(folder, fname),
            'true_label' : cls,
            'pred_label' : class_config[cls]['preds'][i],
            'confidence' : class_config[cls]['confs'][i],
        })

# ── plot: 5 rows (one per class) × 5 cols ───────────────────────────────────
fig, axes = plt.subplots(5, 5, figsize=(18, 20))

for i, e in enumerate(entries):
    row = i // 5
    col = i  % 5
    ax  = axes[row][col]

    color = 'green' if e['pred_label'] == e['true_label'] else 'red'

    ax.imshow(image.load_img(e['fpath'], target_size=IMG_SIZE))
    ax.set_title(
        f"True : {e['true_label'].upper()}\n"
        f"Pred : {e['pred_label'].upper()}\n"
        f"Conf : {e['confidence']:.1f}%",
        fontsize=9, color=color, fontweight='bold'
    )
    ax.axis('off')

# row labels on the left
for row, cls in enumerate(CLASS_NAMES):
    axes[row][0].set_ylabel(cls.upper(), fontsize=12, fontweight='bold', rotation=90, labelpad=10)

total   = len(entries)
correct = sum(1 for e in entries if e['pred_label'] == e['true_label'])
wrong   = total - correct

plt.suptitle(
    f'Test Results — All 5 Classes  | {correct} Correct {wrong} Wrong   out of {total}',
    fontsize=14, fontweight='bold'
)
plt.tight_layout()
plt.show()
